# %% [markdown]
# **instructions**

# %% [markdown]
# # IoT → Buffer (file-based) → Spark Structured Streaming → Storage → Visualization + ML
# Run cells in order. This notebook simulates Kafka by writing JSON files to an input folder and uses Spark Structured Streaming to read them, process them, and write results to Parquet. The ML cell trains an anomaly detector on stored results. If the streaming query is running, you can stop it by calling `query.stop()` in the cell that started it.

# %% [markdown]
# **Install system dependencies and Python packages**

# %%
# !apt-get update -qq
# !apt-get install -y openjdk-11-jdk-headless -qq
# !pip uninstall -y dataproc-spark-connect
# !pip install -q pyspark==3.5.0 findspark plotly pandas scikit-learn pyarrow
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Found existing installation: dataproc-spark-connect 1.0.1
# Uninstalling dataproc-spark-connect-1.0.1:
#   Successfully uninstalled dataproc-spark-connect-1.0.1
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.9/316.9 MB 4.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.5/200.5 kB 13.9 MB/s eta 0:00:00
#   Building wheel for pyspark (setup.py) ... done

# %% [markdown]
# **Set environment variables and initialize findspark**

# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-11-openjdk-amd64"
import findspark
findspark.init()

# %% [markdown]
# **Create required directories for simulated stream, output, and checkpoints**

# %%
import os
base = "/content/iot_stream_pipeline"
input_dir = os.path.join(base, "input")
output_dir = os.path.join(base, "output_parquet")
checkpoint_dir = os.path.join(base, "checkpoint")
os.makedirs(input_dir, exist_ok=True)
os.makedirs(output_dir, exist_ok=True)
os.makedirs(checkpoint_dir, exist_ok=True)

# %% [markdown]
# **Data producer: generate and write N JSON files to simulate IoT streaming**

# %%
import json
import time
import random
from threading import Thread

def produce_messages(num_messages=200, interval=0.5):
    for i in range(num_messages):
        msg = {
            "device_id": random.randint(1,5),
            "temperature": round(random.uniform(18.0,40.0),2),
            "humidity": round(random.uniform(20.0,80.0),2),
            "timestamp": int(time.time()*1000)
        }
        filename = f"msg_{int(time.time()*1000)}_{i}.json"
        path = os.path.join(input_dir, filename)
        with open(path, "w") as f:
            f.write(json.dumps(msg))
        time.sleep(interval)

producer_thread = Thread(target=produce_messages, kwargs={"num_messages":2000,"interval":0.1}, daemon=True)
producer_thread.start()

# %% [markdown]
# **Create Spark session with required configs**

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("IoTStreamingPipeline").getOrCreate()

# %% [markdown]
# **Define schema, read streaming JSON from input folder, and basic transformations**

# %%
from pyspark.sql.types import StructType, StructField, IntegerType, DoubleType, LongType
from pyspark.sql.functions import from_unixtime, col, window

schema = StructType([
    StructField("device_id", IntegerType(), True),
    StructField("temperature", DoubleType(), True),
    StructField("humidity", DoubleType(), True),
    StructField("timestamp", LongType(), True)
])

stream_df = spark.readStream.schema(schema).json(input_dir)
stream_df = stream_df.withColumn("event_time", (col("timestamp")/1000).cast("timestamp"))

stream_df = stream_df.withWatermark("event_time", "20 seconds")

agg_df = stream_df.groupBy(
    window(col("event_time"), "10 seconds"),
    col("device_id")
).avg("temperature", "humidity").select(
    col("window.start").alias("window_start"),
    col("window.end").alias("window_end"),
    col("device_id"),
    col("avg(temperature)").alias("avg_temperature"),
    col("avg(humidity)").alias("avg_humidity")
)

# %% [markdown]
# **Start streaming query to write aggregated results to Parquet , and capture query in variable**

# %%
query = agg_df.writeStream.format("parquet").option("path", output_dir).option("checkpointLocation", checkpoint_dir).outputMode("append").start()

# %% [markdown]
# **Let the streaming query run for a fixed time**

# %%
time.sleep(40)
query.stop()

# %% [markdown]
# **Inspect the Parquet output with Spark and show a sample**

# %%
result_df = spark.read.parquet(output_dir)
result_df.orderBy("window_start", "device_id").show(20, False)
# Out:
# +-------------------+-------------------+---------+------------------+------------------+
# |window_start       |window_end         |device_id|avg_temperature   |avg_humidity      |
# +-------------------+-------------------+---------+------------------+------------------+
# |2025-12-12 09:23:00|2025-12-12 09:23:10|1        |27.2475           |53.67875          |
# |2025-12-12 09:23:00|2025-12-12 09:23:10|2        |31.50333333333333 |60.47666666666667 |
# |2025-12-12 09:23:00|2025-12-12 09:23:10|3        |35.57             |24.74             |
# |2025-12-12 09:23:00|2025-12-12 09:23:10|4        |30.085            |68.2              |
# |2025-12-12 09:23:00|2025-12-12 09:23:10|5        |26.325000000000003|47.275            |
# |2025-12-12 09:23:10|2025-12-12 09:23:20|1        |32.62444444444444 |53.797777777777775|
# |2025-12-12 09:23:10|2025-12-12 09:23:20|2        |29.356666666666666|39.135000000000005|
# |2025-12-12 09:23:10|2025-12-12 09:23:20|3        |27.72666666666667 |44.41166666666667 |
# |2025-12-12 09:23:10|2025-12-12 09:23:20|4        |27.396666666666665|55.51166666666666 |
# |2025-12-12 09:23:10|2025-12-12 09:23:20|5        |26.245            |36.431666666666665|
# |2025-12-12 09:23:20|2025-12-12 09:23:30|1        |26.87833333333333 |52.94833333333333 |
# |2025-12-12 09:23:20|2025-12-12 09:23:30|2        |21.338333333333335|45.385            |
# |2025-12-12 09:23:20|2025-12-12 09:23:30|3        |31.275555555555552|61.13666666666667 |
# |2025-12-12 09:23:20|2025-12-12 09:23:30|4        |33.839999999999996|45.54333333333333 |
# |2025-12-12 09:23:20|2025-12-12 09:23:30|5        |26.896666666666665|48.50333333333333 |
# |2025-12-12 09:23:30|2025-12-12 09:23:40|1        |29.086250000000003|47.01499999999999 |
# |2025-12-12 09:23:30|2025-12-12 09:23:40|2        |33.75571428571429 |46.808571428571426|
# |2025-12-12 09:23:30|2025-12-12 09:23:40|3        |28.885            |33.28333333333333 |
# |2025-12-12 09:23:30|2025-12-12 09:23:40|4        |28.310000000000002|46.63333333333333 |
# |2025-12-12 09:23:30|2025-12-12 09:23:40|5        |26.218333333333334|46.041666666666664|
# +-------------------+-------------------+---------+------------------+------------------+
# only showing top 20 rows

# %% [markdown]
# **Subplots Per device**

# %%
import pandas as pd
pdf = result_df.toPandas()

if pdf.shape[0] == 0:
    print("No processed records found yet. Re-run producer or allow streaming to run longer.")
else:
    pdf["window_start"] = pd.to_datetime(pdf["window_start"])
    import plotly.express as px
    fig = px.line(
        pdf,
        x="window_start",
        y="avg_temperature",
        facet_row="device_id",
        title="Avg Temperature per Device (10s window)",
        height=900
    )
    fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8552e870-0dcf-4924-b748-ca5ff0278239" class="plotly-graph-div" style="height:900px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8552e870-0dcf-4924-b748-ca5ff0278239")) {                    Plotly.newPlot(                        "8552e870-0dcf-4924-b748-ca5ff0278239",                        [{"hovertemplate":"device_id=4\u003cbr\u003ewindow_start=%{x}\u003cbr\u003eavg_temperature=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2025-12-12T09:24:00","2025-12-12T09:23:30","2025-12-12T09:23:50","2025-12-12T09:23:40","2025-12-12T09:23:10","2025-12-12T09:23:20","2025-12-12T09:23:00","2025-12-12T09:24:20","2025-12-12T09:24:10","2025-12-12T09:24:30"],"xaxis":"x5","y":[29.155,28.310000000000002,28.856,31.4275,27.396666666666665,33.839999999999996,30.085,26.866666666666664,27.46625,26.71],"yaxis":"y5","type":"scatter"},{"hovertemplate":"device_id=2\u003cbr\u003ewindow_start=%{x}\u003cbr\u003eavg_temperature=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2025-12-12T09
"y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0. ...

# %% [markdown]
# **Save processed Parquet as a single consolidated CSV for ML and report artifacts**

# %%
artifacts_dir = os.path.join(base, "artifacts")
os.makedirs(artifacts_dir, exist_ok=True)
consolidated_csv = os.path.join(artifacts_dir, "aggregated_results.csv")
pdf.to_csv(consolidated_csv, index=False)
print(consolidated_csv)
# Out:
# /content/iot_stream_pipeline/artifacts/aggregated_results.csv

# %% [markdown]
# **ML: train an IsolationForest anomaly detector on avg_temperature and avg_humidity**

# %%
from sklearn.ensemble import IsolationForest
import numpy as np

X = pdf[["avg_temperature", "avg_humidity"]].values
if X.shape[0] < 10:
    print("Not enough rows for reliable ML; produce more data and re-run this cell.")
else:
    iso = IsolationForest(contamination=0.10, random_state=42)
    iso.fit(X)
    preds = iso.predict(X)
    pdf["anomaly"] = np.where(preds == -1, 1, 0)
    anomalies = pdf[pdf["anomaly"] == 1]
    print("Anomalies detected:", anomalies.shape[0])
    display(anomalies.head(10))
# Out:
# Anomalies detected: 5
#           window_start          window_end  device_id  avg_temperature  \
# 7  2025-12-12 09:23:00 2025-12-12 09:23:10          3        35.570000
# 16 2025-12-12 09:23:20 2025-12-12 09:23:30          2        21.338333
# 24 2025-12-12 09:23:00 2025-12-12 09:23:10          4        30.085000
# 25 2025-12-12 09:23:50 2025-12-12 09:24:00          2        36.677500
# 28 2025-12-12 09:24:20 2025-12-12 09:24:30          3        31.398000
#
#     avg_humidity  anomaly
# 7        24.7400        1
# 16       45.3850        1
# 24       68.2000        1
# 25       51.2575        1
# 28       33.4500        1

# %% [markdown]
# **Subplots Showing Anomalies**

# %%
if "anomaly" in pdf.columns:
    import plotly.express as px
    df_plot = pdf.copy()
    df_plot["anomaly_label"] = df_plot["anomaly"].map({0: "Normal", 1: "Anomaly"})
    fig = px.scatter(
        df_plot,
        x="window_start",
        y="avg_temperature",
        color="anomaly_label",
        facet_row="device_id",
        title="Avg Temperature with Anomalies Highlighted per Device",
        height=900
    )
    fig.show()
else:
    print("No anomaly data found. Run the ML cell first.")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="fb9a62da-f322-4eba-ab4c-5a4b5c78622b" class="plotly-graph-div" style="height:900px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fb9a62da-f322-4eba-ab4c-5a4b5c78622b")) {                    Plotly.newPlot(                        "fb9a62da-f322-4eba-ab4c-5a4b5c78622b",                        [{"hovertemplate":"anomaly_label=Normal\u003cbr\u003edevice_id=4\u003cbr\u003ewindow_start=%{x}\u003cbr\u003eavg_temperature=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Normal","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Normal","orientation":"v","showlegend":true,"x":["2025-12-12T09:24:00","2025-12-12T09:23:30","2025-12-12T09:23:50","2025-12-12T09:23:40","2025-12-12T09:23:10","2025-12-12T09:23:20","2025-12-12T09:24:20","2025-12-12T09:24:10","2025-12-12T09:24:30"],"xaxis":"x5","y":[29.155,28.310000000000002,28.856,31.4275,27.396666666666665,33.839999999999996,26.866666666666664,27.46625,26.71],"yaxis":"y5","type":"scatter"},{"hovertemplate":"anomaly_label=Normal\u003cbr\u003edevice_id=2\u003cbr\u003ewindow_start=%{x}\u003cbr\u003eavg_temperature=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Normal","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Normal","orientation":"v","showlegend":false,"x":["2025-12-12T09:24:00","2025-12-12T09:23:10","2025-12-12T09:23:40","2025-12-12T09:23:00","2025-12-12T09:24:20","2025-12-12T09:24:10","2025-12-12T09:24:30","2025-12-12T09:23:30"],"xaxis":"x4","y":[30.74,29.356666666666666,28.786666666666665,31.50333333333333,34.945,27.89,33.0625,33.75571428571429],"yaxis":"y4","type":"scatter"},{"hovertemplate":"anomaly_label=Normal\u003cbr\u003edevice_id=5\u003cbr\u003ewindow_start=%{x}\u003cbr\u003eavg_temperature=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Normal","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Normal","orientation":"v","showlegend":false,"x":["2025-12-12T09:23:10","2025-12-12T09:24:00","2025-12-12T09:23:30","2025-12-12T09:23:00","2025-12-12T09:23:40","2025-12-12T09:23:50","2025-12-12T09:24:20","2025-12-12T09:24:30","2025-12-12T09:24:10","2025-12-12T09:23:20"],"xaxis":"x3","y":[26.245,28.317500000000003,26.218333333333334,26.325000000000003,27.692857142857143,28.26666666666667,31.93,29.768,29.364444444444448,26.896666666666665],"yaxis":"y3","type":"scatter"},{"hovertemplate":"anomaly_label=Normal\u003cbr\u003edevice_id=3\u003cbr\u003ewindow_start=%{x}\u003cbr\u003eavg_temperature=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Normal","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Normal","orientation":"v","showlegend":false,"x":["2025-12-12T09:23:20","2025-12-12T09:23:10","2025-12-12T09:24:10","2025-12-12T09:24:30","2025-12-12T09:23:40","2025-12-12T09:23:50","2025-12-12T09:23:30","2025-12-12T09:24:00"],"xaxis":"x2","y":[31.275555555555552,27.72666666666667,29.026666666666667,29.3025,27.444285714285716,33.35285714285714,28.885,30.2525],"yaxis":"y2","type":"scatter"},{"hovertemplate":"anomaly_label=Normal\u003cbr\u003edevice_id=1\u003cbr\u003ewindow_start=%{x}\u003cbr\u003eavg_temperature=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Normal","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Normal","orientation":"v","showlegend":false,"x":["2025-12-12T09:23:10","2025-12-12T09:23:50","2025-12-12T09:23:30","2025-12-12T09:23:00","2025-12-12T09:23:40","2025-12-12T09:23:20","2025-12-12T09:24:20","2025-12-12T09:24:30","2025-12-12T09:24:00","2025-12-12T09:24:10"],"xaxis":"x","y":[32.62444444444444,27.362222222222222,29.086250000000003,27.2475,25.712,26.87833333333333,27.212500000000002,27.487499999999997,26.799999999999997,29.712857142857143],"y ...

# %% [markdown]
# **Plot Only Anomalies**

# %%
if "anomaly" in pdf.columns:
    anomalies = pdf[pdf["anomaly"] == 1]
    if anomalies.shape[0] > 0:
        import plotly.express as px
        fig = px.scatter(
            anomalies,
            x="window_start",
            y="avg_temperature",
            color="device_id",
            title="Detected Anomalies Only — All Devices",
            size=[10]*len(anomalies)
        )
        fig.show()
    else:
        print("ML model found no anomalies.")
else:
    print("Run the ML cell to generate anomaly labels first.")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="05f2b6d6-83f7-4cfc-b8c2-866e4bbccc5d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("05f2b6d6-83f7-4cfc-b8c2-866e4bbccc5d")) {                    Plotly.newPlot(                        "05f2b6d6-83f7-4cfc-b8c2-866e4bbccc5d",                        [{"hovertemplate":"window_start=%{x}\u003cbr\u003eavg_temperature=%{y}\u003cbr\u003esize=%{marker.size}\u003cbr\u003edevice_id=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[3,2,4,2,3],"coloraxis":"coloraxis","size":[10,10,10,10,10],"sizemode":"area","sizeref":0.025,"symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":["2025-12-12T09:23:00","2025-12-12T09:23:20","2025-12-12T09:23:00","2025-12-12T09:23:50","2025-12-12T09:24:20"],"xaxis":"x","y":[35.57,21.338333333333335,30.085,36.6775,31.398000000000003],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"# ...

# %% [markdown]
# **Saving everything into a zip file**

# %%
import shutil
zip_path = "/content/iot_pipeline_artifacts.zip"
shutil.make_archive("/content/iot_pipeline_artifacts", "zip", base)
print(zip_path)
# Out:
# /content/iot_pipeline_artifacts.zip
